# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PolynomialFeatures, RobustScaler 
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import KNeighborsClassifier

# %%
dataset = pd.read_csv("data.csv")
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
validation = pd.read_csv("validation.csv")

#F1, F2, F1/2, Macro

# %%
dataset.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# 50%                                   0.559802
# 75%                                   0.589157
# max                                   1.000000
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        6819.000000
# mean                                            0.553589
# std                                             0.061595
# min                                             0.000000
# 25%                                             0.527277
# 50%                                             0.552278
# 75%                                             0.584105
# max                                             1.000000
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              6819.000000                   6819.000000
# mean                  0.607948                      0.607929
# std                   0.016934                      0.016916
# min                   0.000000                      0.000000
# 25%                   0.600445                      0.600434
# 50%                   0.605997                      0.605976
# 75%                   0.613914                      0.613842
# max                   1.000000                      1.000000
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             6819.000000                 6819.000000
# mean                 0.998755                    0.797190
# std                  0.013010                    0.012869
# min                  0.000000                    0.000000
# 25%                  0.998969                    0.797386
# 50%                  0.999022                    0.797464
# 75%                  0.999095                    0.797579
# max                  1.000000                    1.000000
#
#         After-tax net Interest Rate  \
# count                   6819.000000
# mean                       0.809084
# std                        0.013601
# min                        0.000000
# 25%                        0.809312
# 50%                        0.809375
# 75%                        0.809469
# max                        1.000000
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   6819.000000  ...
# mean                                       0.303623  ...
# std                                        0.011163  ...
# min                                        0.000000  ...
# 25%                                        0.303466  ...
# 50%                                        0.303525  ...
# 75%                                        0.303585  ...
# max                                        1.000000  ...
#
#         Net Income to Total Assets   Total assets to GNP price  \
# count                  6819.000000                6.819000e+03
# mean                      0.807760                1.862942e+07
# std                       0.040332                3.764501e+08
# min                       0.000000                0.000000e+00
# 25%                       0.796750                9.036205e-04
# 50%                       0.810619                2.085213e-03
# 75%                       0.826455                5.269777e-03
# max                       1.000000                9.820000e+09
#
#         No-credit Interval   Gross Profit to Sales  \
# count          6819.000000             6819.000000
# mean              0.623915                0.607946
# std               0.012290                0.016934
# min               0.000000                0.000000
# 25%               0.623636                0.600443
# 50%               0.623879                0.605998
# 75%               0.624168                0.613913
# max               1.000000                1.000000
#
#         Net Income to Stockholder's Equity   Liability to Equity  \
# count                          6819.000000           6819.000000
# mean                              0.840402              0.280365
# std                               0.014523              0.014463
# min                               0.000000              0.000000
# 25%                               0.840115              0.276944
# 50%                               0.841179              0.278778
# 75%                               0.842357              0.281449
# max                               1.000000              1.000000
#
#         Degree of Financial Leverage (DFL)  \
# count                          6819.000000
# mean                              0.027541
# std                               0.015668
# min                               0.000000
# 25%                               0.026791
# 50%                               0.026808
# 75%                               0.026913
# max                               1.000000
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        6819.000000              6819.0
# mean                                            0.565358                 1.0
# std                                             0.013214                 0.0
# min                                             0.000000                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565252                 1.0
# 75%                                             0.565725                 1.0
# max                                             1.000000                 1.0
#
#         Equity to Liability
# count           6819.000000
# mean               0.047578
# std                0.050014
# min                0.000000
# 25%                0.024477
# 50%                0.033798
# 75%                0.052838
# max                1.000000
#
# [8 rows x 96 columns]

# %%
train.describe()
# Out:
#         Unnamed: 0   ROA(C) before interest and depreciation before interest  \
# count  3426.000000                                        3426.000000
# mean   3450.276416                                           0.506435
# std    1975.638584                                           0.061262
# min       2.000000                                           0.066933
# 25%    1739.750000                                           0.476917
# 50%    3461.500000                                           0.504485
# 75%    5176.500000                                           0.537708
# max    6818.000000                                           0.971530
#
#         ROA(A) before interest and % after tax  \
# count                              3426.000000
# mean                                  0.559637
# std                                   0.065703
# min                                   0.057185
# 25%                                   0.536551
# 50%                                   0.561328
# 75%                                   0.590547
# max                                   1.000000
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        3426.000000
# mean                                            0.554770
# std                                             0.061740
# min                                             0.054821
# 25%                                             0.527705
# 50%                                             0.553857
# 75%                                             0.585618
# max                                             1.000000
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              3426.000000                   3426.000000
# mean                  0.608186                      0.608175
# std                   0.018389                      0.018371
# min                   0.000000                      0.000000
# 25%                   0.600628                      0.600643
# 50%                   0.606235                      0.606289
# 75%                   0.614249                      0.614242
# max                   1.000000                      1.000000
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             3426.000000                 3426.000000
# mean                 0.998830                    0.797207
# std                  0.006723                    0.011965
# min                  0.612132                    0.160516
# 25%                  0.998971                    0.797388
# 50%                  0.999026                    0.797469
# 75%                  0.999100                    0.797587
# max                  0.999778                    1.000000
#
#         After-tax net Interest Rate  \
# count                   3426.000000
# mean                       0.809061
# std                        0.014631
# min                        0.000000
# 25%                        0.809313
# 50%                        0.809380
# 75%                        0.809475
# max                        1.000000
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   3426.000000  ...
# mean                                       0.303496  ...
# std                                        0.010280  ...
# min                                        0.000000  ...
# 25%                                        0.303470  ...
# 50%                                        0.303526  ...
# 75%                                        0.303588  ...
# max                                        0.730252  ...
#
#         Total assets to GNP price   No-credit Interval  \
# count                3.426000e+03          3426.000000
# mean                 2.144483e+07             0.623835
# std                  4.158484e+08             0.015073
# min                  1.015558e-04             0.000000
# 25%                  9.166054e-04             0.623637
# 50%                  2.119917e-03             0.623877
# 75%                  5.277196e-03             0.624188
# max                  9.820000e+09             1.000000
#
#         Gross Profit to Sales   Net Income to Stockholder's Equity  \
# count             3426.000000                          3426.000000
# mean                 0.608185                             0.840542
# std                  0.018389                             0.011471
# min                  0.000000                             0.344652
# 25%                  0.600623                             0.840142
# 50%                  0.606234                             0.841229
# 75%                  0.614247                             0.842399
# max                  1.000000                             1.000000
#
#         Liability to Equity   Degree of Financial Leverage (DFL)  \
# count           3426.000000                          3426.000000
# mean               0.280262                             0.027630
# std                0.009919                             0.020390
# min                0.182790                             0.000000
# 25%                0.276879                             0.026791
# 50%                0.278779                             0.026808
# 75%                0.281352                             0.026910
# max                0.643692                             1.000000
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        3426.000000              3426.0
# mean                                            0.565297                 1.0
# std                                             0.012827                 0.0
# min                                             0.000000                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565250                 1.0
# 75%                                             0.565708                 1.0
# max                                             0.735958                 1.0
#
#         Equity to Liability    Bankrupt?
# count           3426.000000  3426.000000
# mean               0.048536     0.030064
# std                0.053828     0.170789
# min                0.000000     0.000000
# 25%                0.024698     0.000000
# 50%                0.033787     0.000000
# 75%                0.054145     0.000000
# max                1.000000     1.000000
#
# [8 rows x 97 columns]

# %%
test.describe()
# Out:
#         Unnamed: 0   ROA(C) before interest and depreciation before interest  \
# count  2251.000000                                        2251.000000
# mean   3364.282985                                           0.502955
# std    1978.474584                                           0.059301
# min       8.000000                                           0.024277
# 25%    1616.500000                                           0.475991
# 50%    3347.000000                                           0.500658
# 75%    5080.000000                                           0.533467
# max    6817.000000                                           0.755131
#
#         ROA(A) before interest and % after tax  \
# count                              2251.000000
# mean                                  0.556458
# std                                   0.064999
# min                                   0.000000
# 25%                                   0.533908
# 50%                                   0.558548
# 75%                                   0.586541
# max                                   0.954536
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        2251.000000
# mean                                            0.551477
# std                                             0.060799
# min                                             0.033514
# 25%                                             0.526929
# 50%                                             0.550511
# 75%                                             0.582365
# max                                             0.798223
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              2251.000000                   2251.000000
# mean                  0.607777                      0.607756
# std                   0.016654                      0.016637
# min                   0.156308                      0.156308
# 25%                   0.600239                      0.600232
# 50%                   0.605810                      0.605796
# 75%                   0.613698                      0.613619
# max                   0.665151                      0.666023
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             2251.000000                 2251.000000
# mean                 0.998516                    0.797033
# std                  0.021070                    0.016841
# min                  0.000000                    0.000000
# 25%                  0.998966                    0.797383
# 50%                  0.999020                    0.797457
# 75%                  0.999088                    0.797571
# max                  1.000000                    0.809513
#
#         After-tax net Interest Rate  \
# count                   2251.000000
# mean                       0.808980
# std                        0.015311
# min                        0.084286
# 25%                        0.809309
# 50%                        0.809369
# 75%                        0.809461
# max                        0.821053
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   2251.000000  ...
# mean                                       0.303850  ...
# std                                        0.014701  ...
# min                                        0.295983  ...
# 25%                                        0.303464  ...
# 50%                                        0.303526  ...
# 75%                                        0.303582  ...
# max                                        1.000000  ...
#
#         Total assets to GNP price   No-credit Interval  \
# count                2.251000e+03          2251.000000
# mean                 1.954687e+07             0.623833
# std                  3.587710e+08             0.006573
# min                  0.000000e+00             0.528279
# 25%                  8.839498e-04             0.623628
# 50%                  2.041545e-03             0.623874
# 75%                  5.318046e-03             0.624137
# max                  9.650000e+09             0.797385
#
#         Gross Profit to Sales   Net Income to Stockholder's Equity  \
# count             2251.000000                          2251.000000
# mean                 0.607776                             0.840406
# std                  0.016654                             0.010643
# min                  0.156309                             0.442176
# 25%                  0.600237                             0.840069
# 50%                  0.605810                             0.841102
# 75%                  0.613695                             0.842318
# max                  0.665149                             0.976180
#
#         Liability to Equity   Degree of Financial Leverage (DFL)  \
# count           2251.000000                          2251.000000
# mean               0.280515                             0.027247
# std                0.019027                             0.004872
# min                0.000000                             0.000789
# 25%                0.277008                             0.026791
# 50%                0.278855                             0.026808
# 75%                0.281615                             0.026910
# max                1.000000                             0.174091
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        2251.000000              2251.0
# mean                                            0.565348                 1.0
# std                                             0.015792                 0.0
# min                                             0.172065                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565247                 1.0
# 75%                                             0.565721                 1.0
# max                                             1.000000                 1.0
#
#         Equity to Liability    Bankrupt?
# count           2251.000000  2251.000000
# mean               0.046058     0.035984
# std                0.043373     0.186292
# min                0.008500     0.000000
# 25%                0.024110     0.000000
# 50%                0.033388     0.000000
# 75%                0.051646     0.000000
# max                0.920638     1.000000
#
# [8 rows x 97 columns]

# %%
validation.describe()
# Out:
#         Unnamed: 0   ROA(C) before interest and depreciation before interest  \
# count  1142.000000                                        1142.000000
# mean   3373.312609                                           0.505798
# std    1926.687142                                           0.061571
# min       0.000000                                           0.000000
# 25%    1761.500000                                           0.476417
# 50%    3393.500000                                           0.501267
# 75%    5001.250000                                           0.534320
# max    6807.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              1142.000000
# mean                                  0.559860
# std                                   0.066534
# min                                   0.006923
# 25%                                   0.535543
# 50%                                   0.559147
# 75%                                   0.589730
# max                                   0.984736
#
#         ROA(B) before interest and depreciation after tax  \
# count                                        1142.000000
# mean                                            0.554208
# std                                             0.062654
# min                                             0.000000
# 25%                                             0.527129
# 50%                                             0.550618
# 75%                                             0.582566
# max                                             0.957760
#
#         Operating Gross Margin   Realized Sales Gross Margin  \
# count              1142.000000                   1142.000000
# mean                  0.607569                      0.607534
# std                   0.012291                      0.012272
# min                   0.494249                      0.494249
# 25%                   0.600284                      0.600234
# 50%                   0.605576                      0.605529
# 75%                   0.613172                      0.613175
# max                   0.664192                      0.664192
#
#         Operating Profit Rate   Pre-tax net Interest Rate  \
# count             1142.000000                 1142.000000
# mean                 0.999002                    0.797447
# std                  0.000271                    0.000717
# min                  0.994427                    0.789248
# 25%                  0.998970                    0.797386
# 50%                  0.999015                    0.797458
# 75%                  0.999085                    0.797566
# max                  0.999557                    0.812848
#
#         After-tax net Interest Rate  \
# count                   1142.000000
# mean                       0.809356
# std                        0.000645
# min                        0.801097
# 25%                        0.809311
# 50%                        0.809374
# 75%                        0.809465
# max                        0.822551
#
#         Non-industry income and expenditure/revenue  ...  \
# count                                   1142.000000  ...
# mean                                       0.303556  ...
# std                                        0.001083  ...
# min                                        0.293829  ...
# 25%                                        0.303459  ...
# 50%                                        0.303524  ...
# 75%                                        0.303585  ...
# max                                        0.330080  ...
#
#         Total assets to GNP price   No-credit Interval  \
# count                1.142000e+03          1142.000000
# mean                 8.374781e+06             0.624315
# std                  2.715942e+08             0.011622
# min                  1.036447e-04             0.557613
# 25%                  8.919306e-04             0.623652
# 50%                  2.055697e-03             0.623889
# 75%                  5.082890e-03             0.624199
# max                  9.170000e+09             0.956387
#
#         Gross Profit to Sales   Net Income to Stockholder's Equity  \
# count             1142.000000                          1142.000000
# mean                 0.607568                             0.839974
# std                  0.012291                             0.025331
# min                  0.494250                             0.000000
# 25%                  0.600284                             0.840115
# 50%                  0.605572                             0.841126
# 75%                  0.613169                             0.842301
# max                  0.664191                             0.885473
#
#         Liability to Equity   Degree of Financial Leverage (DFL)  \
# count           1142.000000                          1142.000000
# mean               0.280379                             0.027855
# std                0.015513                             0.013105
# min                0.133503                             0.020713
# 25%                0.277045                             0.026791
# 50%                0.278596                             0.026812
# 75%                0.281458                             0.026929
# max                0.745352                             0.367190
#
#         Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# count                                        1142.000000              1142.0
# mean                                            0.565561                 1.0
# std                                             0.007592                 0.0
# min                                             0.449255                 1.0
# 25%                                             0.565158                 1.0
# 50%                                             0.565275                 1.0
# 75%                                             0.565795                 1.0
# max                                             0.736985                 1.0
#
#         Equity to Liability    Bankrupt?
# count           1142.000000  1142.000000
# mean               0.047704     0.031524
# std                0.050322     0.174805
# min                0.009546     0.000000
# 25%                0.024446     0.000000
# 50%                0.034915     0.000000
# 75%                0.051121     0.000000
# max                0.881018     1.000000
#
# [8 rows x 97 columns]

# %%
dataset.info()

# features to drop
 # 2, 3
    
# features to keep
    # Current Ratio
    # Sales / Total Assets
    # Working Capital/Total Assets
    # Earning before interest and taxes / Total Assets
    # Cash Flow/ Debt
    # Equity Market Value /Total Liabilities
    # Cash Flow /Sales
    # Debt / Equity
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
#  8    After-tax net Interest Rate                              6819 non-null   float64
#  9    Non-industry income and expenditure/revenue              6819 non-null   float64
#  10   Continuous interest rate (after tax)                     6819 non-null   float64
#  11   Operating Expense Rate                                   6819 non-null   float64
#  12   Research and development expense rate                    6819 non-null   float64
#  13   Cash flow rate                                           6819 non-null   float64
#  14   Interest-bearing debt interest rate                      6819 non-null   float64
#  15   Tax rate (A)                                             6819 non-null   float64
#  16   Net Value Per Share (B)                                  6819 non-null   float64
#  17   Net Value Per Share (A)                                  6819 non-null   float64
#  18   Net Value Per Share (C)                                  6819 non-null   float64
#  19   Persistent EPS in the Last Four Seasons                  6819 non-null   float64
#  20   Cash Flow Per Share                                      6819 non-null   float64
#  21   Revenue Per Share (Yuan ¥)                               6819 non-null   float64
#  22   Operating Profit Per Share (Yuan ¥)                      6819 non-null   float64
#  23   Per Share Net profit before tax (Yuan ¥)                 6819 non-null   float64
#  24   Realized Sales Gross Profit Growth Rate                  6819 non-null   float64
#  25   Operating Profit Growth Rate                             6819 non-null   float64
#  26   After-tax Net Profit Growth Rate                         6819 non-null   float64
#  27   Regular Net Profit Growth Rate                           6819 non-null   float64
#  28   Continuous Net Profit Growth Rate                        6819 non-null   float64
#  29   Total Asset Growth Rate                                  6819 non-null   float64
#  30   Net Value Growth Rate                                    6819 non-null   float64
#  31   Total Asset Return Growth Rate Ratio                     6819 non-null   float64
#  32   Cash Reinvestment %                                      6819 non-null   float64
#  33   Current Ratio                                            6819 non-null   float64
#  34   Quick Ratio                                              6819 non-null   float64
#  35   Interest Expense Ratio                                   6819 non-null   float64
#  36   Total debt/Total net worth                               6819 non-null   float64
#  37   Debt ratio %                                             6819 non-null   float64
#  38   Net worth/Assets                                         6819 non-null   float64
#  39   Long-term fund suitability ratio (A)                     6819 non-null   float64
#  40   Borrowing dependency                                     6819 non-null   float64
#  41   Contingent liabilities/Net worth                         6819 non-null   float64
#  42   Operating profit/Paid-in capital                         6819 non-null   float64
#  43   Net profit before tax/Paid-in capital                    6819 non-null   float64
#  44   Inventory and accounts receivable/Net value              6819 non-null   float64
#  45   Total Asset Turnover                                     6819 non-null   float64
#  46   Accounts Receivable Turnover                             6819 non-null   float64
#  47   Average Collection Days                                  6819 non-null   float64
#  48   Inventory Turnover Rate (times)                          6819 non-null   float64
#  49   Fixed Assets Turnover Frequency                          6819 non-null   float64
#  50   Net Worth Turnover Rate (times)                          6819 non-null   float64
#  51   Revenue per person                                       6819 non-null   float64
#  52   Operating profit per person                              6819 non-null   float64
#  53   Allocation rate per person                               6819 non-null   float64
#  54   Working Capital to Total Assets                          6819 non-null   float64
#  55   Quick Assets/Total Assets                                6819 non-null   float64
#  56   Current Assets/Total Assets                              6819 non-null   float64
#  57   Cash/Total Assets                                        6819 non-null   float64
#  58   Quick Assets/Current Liability                           6819 non-null   float64
#  59   Cash/Current Liability                                   6819 non-null   float64
#  60   Current Liability to Assets                              6819 non-null   float64
#  61   Operating Funds to Liability                             6819 non-null   float64
#  62   Inventory/Working Capital                                6819 non-null   float64
#  63   Inventory/Current Liability                              6819 non-null   float64
#  64   Current Liabilities/Liability                            6819 non-null   float64
#  65   Working Capital/Equity                                   6819 non-null   float64
#  66   Current Liabilities/Equity                               6819 non-null   float64
#  67   Long-term Liability to Current Assets                    6819 non-null   float64
#  68   Retained Earnings to Total Assets                        6819 non-null   float64
#  69   Total income/Total expense                               6819 non-null   float64
#  70   Total expense/Assets                                     6819 non-null   float64
#  71   Current Asset Turnover Rate                              6819 non-null   float64
#  72   Quick Asset Turnover Rate                                6819 non-null   float64
#  73   Working capitcal Turnover Rate                           6819 non-null   float64
#  74   Cash Turnover Rate                                       6819 non-null   float64
#  75   Cash Flow to Sales                                       6819 non-null   float64
#  76   Fixed Assets to Assets                                   6819 non-null   float64
#  77   Current Liability to Liability                           6819 non-null   float64
#  78   Current Liability to Equity                              6819 non-null   float64
#  79   Equity to Long-term Liability                            6819 non-null   float64
#  80   Cash Flow to Total Assets                                6819 non-null   float64
#  81   Cash Flow to Liability                                   6819 non-null   float64
#  82   CFO to Assets                                            6819 non-null   float64
#  83   Cash Flow to Equity                                      6819 non-null   float64
#  84   Current Liability to Current Assets                      6819 non-null   float64
#  85   Liability-Assets Flag                                    6819 non-null   int64
#  86   Net Income to Total Assets                               6819 non-null   float64
#  87   Total assets to GNP price                                6819 non-null   float64
#  88   No-credit Interval                                       6819 non-null   float64
#  89   Gross Profit to Sales                                    6819 non-null   float64
#  90   Net Income to Stockholder's Equity                       6819 non-null   float64
#  91   Liability to Equity                                      6819 non-null   float64
#  92   Degree of Financial Leverage (DFL)                       6819 non-null   float64
#  93   Interest Coverage Ratio (Interest expense to EBIT)       6819 non-null   float64
#  94   Net Income Flag                                          6819 non-null   int64
#  95   Equity to Liability                                      6819 non-null   float64
# dtypes: float64(93), int64(3)
# memory usage: 5.0 MB

# %%
dataset.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
#        ' Realized Sales Gross Profit Growth Rate',
#        ' Operating Profit Growth Rate', ' After-tax Net Profit Growth Rate',
#        ' Regular Net Profit Growth Rate', ' Continuous Net Profit Growth Rate',
#        ' Total Asset Growth Rate', ' Net Value Growth Rate',
#        ' Total Asset Return Growth Rate Ratio', ' Cash Reinvestment %',
#        ' Current Ratio', ' Quick Ratio', ' Interest Expense Ratio',
#        ' Total debt/Total net worth', ' Debt ratio %', ' Net worth/Assets',
#        ' Long-term fund suitability ratio (A)', ' Borrowing dependency',
#        ' Contingent liabilities/Net worth',
#        ' Operating profit/Paid-in capital',
#        ' Net profit before tax/Paid-in capital',
#        ' Inventory and accounts receivable/Net value', ' Total Asset Turnover',
#        ' Accounts Receivable Turnover', ' Average Collection Days',
#        ' Inventory Turnover Rate (times)', ' Fixed Assets Turnover Frequency',
#        ' Net Worth Turnover Rate (times)', ' Revenue per person',
#        ' Operating profit per person', ' Allocation rate per person',
#        ' Working Capital to Total Assets', ' Quick Assets/Total Assets',
#        ' Current Assets/Total Assets', ' Cash/Total Assets',
#        ' Quick Assets/Current Liability', ' Cash/Current Liability',
#        ' Current Liability to Assets', ' Operating Funds to Liability',
#        ' Inventory/Working Capital', ' Inventory/Current Liability',
#        ' Current Liabilities/Liability', ' Working Capital/Equity',
#        ' Current Liabilities/Equity', ' Long-term Liability to Current Assets',
#        ' Retained Earnings to Total Assets', ' Total income/Total expense',
#        ' Total expense/Assets', ' Current Asset Turnover Rate',
#        ' Quick Asset Turnover Rate', ' Working capitcal Turnover Rate',
#        ' Cash Turnover Rate', ' Cash Flow to Sales', ' Fixed Assets to Assets',
#        ' Current Liability to Liability', ' Current Liability to Equity',
#        ' Equity to Long-term Liability', ' Cash Flow to Total Assets',
#        ' Cash Flow to Liability', ' CFO to Assets', ' Cash Flow to Equity',
#        ' Current Liability to Current Assets', ' Liability-Assets Flag',
#        ' Net Income to Total Assets', ' Total assets to GNP price',
#        ' No-credit Interval', ' Gross Profit to Sales',
#        ' Net Income to Stockholder's Equity', ' Liability to Equity',
#        ' Degree of Financial Leverage (DFL)',
#        ' Interest Coverage Ratio (Interest expense to EBIT)',
#        ' Net Income Flag', ' Equity to Liability'],
#       dtype='object')

# %%
dataset.isnull().sum().sort_values(ascending=False)
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  Total expense/Assets                                       0
#  Total income/Total expense                                 0
#  Retained Earnings to Total Assets                          0
#                                                            ..
#  Total Asset Growth Rate                                    0
#  Continuous Net Profit Growth Rate                          0
#  Regular Net Profit Growth Rate                             0
#  After-tax Net Profit Growth Rate                           0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
dataset1 = dataset.corr().round(decimals=2)

# %%
# there are no NANs in the dataset, although the "flag" features display NANs in the correlation matrix

# %%
# Data Cleaning: decided not to eliminate outliers as we dont have deep domain knowledge
# EDA: we selected some of the most important features according to fast research to explore the dataset
# Feature Seleccion: we decided to keep all the features
# Running the model: 
    # for every model we decided to apply SMOTE to balance the data and StandardScaler() as baseline variables
    # Models applied:
        # Logistic Regression
        # Random Forest
        # KNN
        # SVM
        # Nayve Base

# %% [markdown]
# ## Logistic Regression

# %%
# Running baseline model
# No features dropped
# SMOTE applied in both train and validation sets

# %%
X_train = train.drop(['Bankrupt?', 'Unnamed: 0'], axis=1)
y_train = train['Bankrupt?']

# %%
X_validation = validation.drop(['Bankrupt?', 'Unnamed: 0'], axis=1)
y_validation = validation['Bankrupt?']

# %%
X_test = test.drop(['Bankrupt?', 'Unnamed: 0'], axis=1)
y_test = test['Bankrupt?']

# %%
preprocessor = StandardScaler()

X_train = preprocessor.fit_transform(X_train)
X_validation = preprocessor.transform(X_validation)

# %%
y_train.value_counts()/len(y_train)
# Out:
# 0    0.969936
# 1    0.030064
# Name: Bankrupt?, dtype: float64

# %%
sm = SMOTE(k_neighbors=3)

X_train_SMOTE, y_train_SMOTE = sm.fit_resample(X_train, y_train)
X_validation_SMOTE, y_validation_SMOTE = sm.fit_resample(X_validation, y_validation)

# %%
y_train_SMOTE.value_counts()/len(y_train_SMOTE)
# Out:
# 0    0.5
# 1    0.5
# Name: Bankrupt?, dtype: float64

# %%
y_validation_SMOTE.value_counts()/len(y_validation_SMOTE)
# Out:
# 0    0.5
# 1    0.5
# Name: Bankrupt?, dtype: float64

# %%
model = LogisticRegression(solver='lbfgs', max_iter=1000)
model.fit(X_train_SMOTE, y_train_SMOTE)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pred_train_SMOTE = model.predict(X_train_SMOTE)
pred_validation_SMOTE = model.predict(X_validation_SMOTE)
print(classification_report(y_train_SMOTE, pred_train_SMOTE))
print(classification_report(y_validation_SMOTE, pred_validation_SMOTE))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92      3323
#            1       0.90      0.93      0.92      3323
#
#     accuracy                           0.92      6646
#    macro avg       0.92      0.92      0.92      6646
# weighted avg       0.92      0.92      0.92      6646
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81      1106
#            1       0.85      0.72      0.78      1106
#
#     accuracy                           0.80      2212
#    macro avg       0.80      0.80      0.79      2212
# weighted avg       0.80      0.80      0.79      2212

# %%
# cm for the train set
cm = confusion_matrix(y_train_SMOTE, model.predict(X_train_SMOTE))
sns.heatmap(cm, annot=True, fmt=".1f")
# Out:
# <AxesSubplot:>

# %%
# cm for the validation set
cm = confusion_matrix(y_validation_SMOTE, model.predict(X_validation_SMOTE))
sns.heatmap(cm, annot=True, fmt=".1f")
# Out:
# <AxesSubplot:>

# %%
preprocessor = StandardScaler()

X_validation_SMOTE = preprocessor.fit_transform(X_validation_SMOTE)
X_test = preprocessor.transform(X_test)

# %%
model = LogisticRegression(solver='lbfgs', max_iter=1000)
model.fit(X_validation_SMOTE, y_validation_SMOTE)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pred_validation_SMOTE = model.predict(X_validation_SMOTE)
pred_test = model.predict(X_test)
print(classification_report(y_validation_SMOTE, pred_validation_SMOTE))
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2491
#            1       0.78      0.37      0.50        78
#
#     accuracy                           0.98      2569
#    macro avg       0.88      0.68      0.75      2569
# weighted avg       0.97      0.98      0.97      2569
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       832
#            1       0.23      0.12      0.16        25
#
#     accuracy                           0.96       857
#    macro avg       0.60      0.55      0.57       857
# weighted avg       0.95      0.96      0.96       857

# %%
from sklearn.metrics import fbeta_score
from sklearn.metrics import f1_score

# %%
f1_score(y_test, pred_test, average='macro')
# Out:
# 0.5694008290415777

# %%
fbeta_score(y_test, pred_test, average='macro', beta=0.5)
# Out:
# 0.5857581107105823

# %%
fbeta_score(y_test, pred_test, average='macro', beta=2)
# Out:
# 0.5589411924418161

# %% [markdown]
# ## KNN

# %%
from sklearn.model_selection import GridSearchCV

# %%
leaf_size = list(range(1,50))
n_neighbors = list(range(1,20))
p=[1,2]
#Convert to dictionary
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
#Create new KNN object
knn_2 = KNeighborsClassifier()
#Use GridSearch
clf = GridSearchCV(knn_2, hyperparameters, cv=10)
#Fit the model
best_model = clf.fit(X_validation_SMOTE,y_validation_SMOTE)
#Print The value of best Hyperparameters
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
# Out:
# Best leaf_size: 1
# Best p: 1
# Best n_neighbors: 4

# %%
knn = KNeighborsClassifier(n_neighbors=4, leaf_size = 1, p = 2)
knn.fit(X_validation_SMOTE, y_validation_SMOTE)
# Out:
# KNeighborsClassifier(leaf_size=1, n_neighbors=4)

# %%
pred_validation_SMOTE = model.predict(X_validation_SMOTE)
pred_test = knn.predict(X_test)
print(classification_report(y_validation_SMOTE, pred_validation_SMOTE))
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      2491
#            1       0.89      0.10      0.18        78
#
#     accuracy                           0.97      2569
#    macro avg       0.93      0.55      0.58      2569
# weighted avg       0.97      0.97      0.96      2569
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       832
#            1       0.50      0.12      0.19        25
#
#     accuracy                           0.97       857
#    macro avg       0.74      0.56      0.59       857
# weighted avg       0.96      0.97      0.96       857

# %%
f1_score(y_test, pred_test, average='macro')
# Out:
# 0.5893469802388208

# %%
fbeta_score(y_test, pred_test, average='macro', beta=0.5)
# Out:
# 0.6423199591451312

# %%
fbeta_score(y_test, pred_test, average='macro', beta=2)
# Out:
# 0.5666867581393039

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 300, min_samples_split = 10, max_depth = 3)
rf.fit(X_validation_SMOTE,y_validation_SMOTE)
# Out:
# RandomForestClassifier(max_depth=3, min_samples_split=10, n_estimators=300)

# %%
pred_validation_SMOTE = rf.predict(X_validation_SMOTE)
pred_test = rf.predict(X_test)
print(classification_report(y_validation_SMOTE, pred_validation_SMOTE))
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2491
#            1       0.94      0.19      0.32        78
#
#     accuracy                           0.98      2569
#    macro avg       0.96      0.60      0.65      2569
# weighted avg       0.97      0.98      0.97      2569
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       832
#            1       1.00      0.04      0.08        25
#
#     accuracy                           0.97       857
#    macro avg       0.99      0.52      0.53       857
# weighted avg       0.97      0.97      0.96       857

# %%
f1_score(y_test, pred_test, average='macro')
# Out:
# 0.5313525337222019

# %%
fbeta_score(y_test, pred_test, average='macro', beta=0.5)
# Out:
# 0.5749287010630023

# %%
fbeta_score(y_test, pred_test, average='macro', beta=2)
# Out:
# 0.5218844064138727

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# %%
svc = SVC()
svc.fit(X_train_SMOTE, y_train_SMOTE)
 
# print prediction results
pred_train_SMOTE = svc.predict(X_train_SMOTE)
pred_validation_SMOTE = rf.predict(X_validation_SMOTE)
print(classification_report(y_train_SMOTE, pred_train_SMOTE))
print(classification_report(y_validation_SMOTE, pred_validation_SMOTE))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.95      3323
#            1       0.93      0.98      0.96      3323
#
#     accuracy                           0.95      6646
#    macro avg       0.96      0.95      0.95      6646
# weighted avg       0.96      0.95      0.95      6646
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      2491
#            1       0.94      0.19      0.32        78
#
#     accuracy                           0.98      2569
#    macro avg       0.96      0.60      0.65      2569
# weighted avg       0.97      0.98      0.97      2569

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid2 = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
 
grid = GridSearchCV(SVC(), param_grid2, refit = True, verbose = 3)
 
# fitting the model for grid search
grid.fit(X_validation_SMOTE, y_validation_SMOTE)

print(grid.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.969 total time=   0.4s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.971 total time=   0.3s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.971 total time=   0.3s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.971 total time=   0.3s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.971 total time=   0.3s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.973 total time=   0.1s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.971 total time=   0.3s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.965 total time=   0.3s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.3s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.971 total time=   0.1s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.963 total time=   0.1s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.975 total time=   0.1s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.973 total time=   0.1s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.977 total time=   0.1s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.975 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.971 total time=   0.3s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.965 total time=   0.3s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.3s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.959 total time=   0.1s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.959 total time=   0.1s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.946 total time=   0.1s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.975 total time=   0.1s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.961 total time=   0.1s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.963 total time=   0.1s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.973 total time=   0.1s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.973 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.971 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.967 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.973 total time=   0.1s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.969 total time=   0.5s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.971 total time=   0.5s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.971 total time=   0.3s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.965 total time=   0.3s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.3s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.967 total time=   0.3s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.969 total time=   0.4s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.965 total time=   0.1s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.957 total time=   0.1s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.949 total time=   0.1s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.942 total time=   0.1s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.963 total time=   0.1s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.965 total time=   0.1s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.965 total time=   0.1s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.961 total time=   0.1s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.955 total time=   0.1s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.973 total time=   0.1s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.973 total time=   0.1s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.969 total time=   0.1s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.963 total time=   0.1s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.967 total time=   0.1s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.975 total time=   0.1s
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# SVC(C=10, gamma=0.001)

# %%
svc = SVC(C=10, gamma=0.001, kernel='rbf')
svc.fit(X_validation_SMOTE, y_validation_SMOTE)
 
# print prediction results
pred_validation_SMOTE = svc.predict(X_validation_SMOTE)
pred_test = rf.predict(X_test)
print(classification_report(y_validation_SMOTE, pred_validation_SMOTE))
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      2491
#            1       0.93      0.17      0.28        78
#
#     accuracy                           0.97      2569
#    macro avg       0.95      0.58      0.63      2569
# weighted avg       0.97      0.97      0.97      2569
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       832
#            1       1.00      0.04      0.08        25
#
#     accuracy                           0.97       857
#    macro avg       0.99      0.52      0.53       857
# weighted avg       0.97      0.97      0.96       857

# %%
f1_score(y_test, pred_test, average='macro')
# Out:
# 0.5313525337222019

# %%
fbeta_score(y_test, pred_test, average='macro', beta=0.5)
# Out:
# 0.5749287010630023

# %%
fbeta_score(y_test, pred_test, average='macro', beta=2)
# Out:
# 0.5218844064138727
